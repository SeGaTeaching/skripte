# %% [markdown]
# # Übungen zu Block 1: Eigene Dekoratoren bauen
#
# ---
# **Aufgabe 1: Ein einfacher "Hallo"-Dekorator**
# Schreiben Sie einen Dekorator namens `@hallo_sagen`, der vor dem Aufruf der dekorierten Funktion einfach "Hallo!" ausgibt.
#
# Testen Sie ihn an einer Funktion `tue_etwas()`, die "Ich tue etwas Wichtiges." ausgibt.
#
# ```python
# # Ihr Code hier
# ```
# ---
# **Aufgabe 2: Argumente akzeptieren**
# Erweitern Sie Ihren Dekorator, sodass er auch mit Funktionen funktioniert, die Argumente entgegennehmen. Nutzen Sie `*args` und `**kwargs` im `wrapper`.
#
# Testen Sie ihn an einer neuen Funktion `addiere(a, b)`, die zwei Zahlen addiert und das Ergebnis zurückgibt. Der Dekorator soll das Ergebnis der Originalfunktion korrekt zurückgeben.
#
# ```python
# # Ihr Code hier
# ```
# ---
# **Aufgabe 3: Ein praktischer `@debug`-Dekorator**
# Erstellen Sie einen Dekorator `@debug`, der vor der Ausführung einer Funktion deren Namen und die übergebenen Argumente ausgibt.
#
# *Beispiel-Ausgabe:* `--- Aufruf von 'multipliziere' mit args=(10, 3), kwargs={} ---`
#
# Testen Sie ihn an der Funktion `multipliziere(x, y)`
#
# ```python
# # Ihr Code hier
# ```
# ---
# **Aufgabe 4 (Fortgeschritten): Ein Dekorator, der selbst ein Argument annimmt**
# Erstellen Sie einen Dekorator `@repeat(n)`, der die dekorierte Funktion `n`-mal hintereinander ausführt.
#
# *Tipp:* Sie benötigen hier eine dreifache Funktions-Verschachtelung: `dekorator(n) -> wrapper(func) -> inner_wrapper(*args, **kwargs)`.
#
# Testen Sie mit `@repeat(3)` auf einer Funktion, die "Wiederholung!" ausgibt.
#
# ```python
# # Ihr Code hier
# ```

# %% [markdown]
# # Übungen zu Block 2: @property für saubere Attribute
#
# ---
# **Aufgabe 1: Read-Only Attribut**
# Erstellen Sie eine Klasse `Person` mit einem "privaten" Instanzattribut `_geburtsjahr`.
# Implementieren Sie eine schreibgeschützte (`read-only`) `@property` namens `alter`, die das ungefähre Alter der Person berechnet und zurückgibt (z.B. `2025 - self._geburtsjahr`).
# Versuchen Sie nach der Erstellung einer Instanz, das Alter zu lesen und dann zu schreiben, um den `AttributeError` zu sehen.
#
# ```python
# # Ihr Code hier
# ```
# ---
# **Aufgabe 2: Property mit Setter**
# Erweitern Sie die Klasse `Person` um einen Setter für das `_geburtsjahr`.
# Erstellen Sie eine Property `geburtsjahr`. Der Getter soll `_geburtsjahr` zurückgeben. Der Setter soll sicherstellen, dass das übergebene Jahr nicht in der Zukunft liegt. Wenn doch, soll eine Fehlermeldung ausgegeben und der Wert nicht geändert werden.
#
# ```python
# # Ihr Code hier
# ```
# ---
# **Aufgabe 3: Sicherer Kontostand**
# Erstellen Sie eine Klasse `Konto` mit einem privaten Attribut `_kontostand`.
# Machen Sie `kontostand` zu einer read-only Property. Der Kontostand soll von außen nicht direkt gesetzt werden können.
#
# ```python
# # Ihr Code hier
# ```
# ---
# **Aufgabe 4: Kontostand sicher verändern**
# Erweitern Sie die `Konto`-Klasse aus Aufgabe 3. Fügen Sie zwei öffentliche Methoden hinzu: `einzahlen(betrag)` und `abheben(betrag)`.
# Diese Methoden sollen die einzige Möglichkeit sein, den privaten `_kontostand` zu verändern. `einzahlen` akzeptiert nur positive Beträge. `abheben` prüft, ob die Deckung ausreicht. Dies ist ein sehr gängiges und sicheres Design-Muster.
#
# ```python
# # Ihr Code hier
# ```

# %% [markdown]
# # Übungen zu Block 3: @classmethod und @staticmethod
#
# **Thema:** Eine `User`-Klasse mit Hilfsfunktionen
# ---
# **Aufgabe 1: Die Basis-Klasse**
# Erstellen Sie eine Klasse `User` mit einem `__init__`, der eine `email` als Instanzattribut speichert.
#
# ```python
# # Ihr Code hier
# ```
# ---
# **Aufgabe 2: Eine statische Validierungs-Methode**
# Fügen Sie eine `@staticmethod` namens `validate_email(email_string)` hinzu. Diese Methode gehört thematisch zur Klasse, braucht aber keinen Zugriff auf Klassen- oder Instanzdaten. Sie soll prüfen, ob der übergebene String ein `@`-Symbol enthält und `True` oder `False` zurückgeben.
#
# ```python
# # Ihr Code hier
# ```
# ---
# **Aufgabe 3: Staticmethod im Konstruktor nutzen**
# Passen Sie den `__init__`-Konstruktor an. Er soll nun die `User.validate_email()`-Methode verwenden, um die übergebene E-Mail zu prüfen. Wenn die E-Mail ungültig ist, soll ein `ValueError` ausgelöst werden.
#
# ```python
# # Ihr Code hier
# ```
# ---
# **Aufgabe 4: Ein alternativer Konstruktor**
# Fügen Sie eine `@classmethod` namens `from_username(cls, username)` hinzu. Diese Methode soll einen einfachen `username` (z.B. "anna") entgegennehmen, daraus eine Standard-E-Mail-Adresse erstellen (z.B. "anna@example.com") und dann eine neue Instanz der `User`-Klasse mit dieser E-Mail zurückgeben.
# Testen Sie, ob Sie mit `User.from_username("max")` ein neues User-Objekt erstellen können.
#
# ```python
# # Ihr Code hier
# ```
