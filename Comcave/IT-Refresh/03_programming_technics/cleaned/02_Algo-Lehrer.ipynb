# %% [markdown]
# ## 📜 **Block 3, Tag 1: Was ist ein Algorithmus? (Theoretische Grundlagen)**
#
# ### **📝 SKRIPT (für Präsentation / Notebook)**
#
# #### **1.1 Herkunft & Definition**
#
# Jedes Mal, wenn wir ein Programm schreiben, erstellen wir einen **Algorithmus**. Das Konzept ist aber viel älter als der Computer selbst. [cite_start]Der Begriff "Algorithmus" ist eine Abwandlung des Namens des persischen Mathematikers **Muhammed al-Chwarizmi**[cite: 307], der um 825 n. [cite_start]Chr. ein bahnbrechendes Lehrbuch über das Rechnen verfasste[cite: 308, 309, 310].
#
# Ein Algorithmus ist im Kern nichts anderes als ein Kochrezept oder eine Bauanleitung. [cite_start]Er legt das **WIE** der Problemlösung fest[cite: 326].
#
# [cite_start]**Definition:** Ein Algorithmus ist eine **genau definierte Handlungsvorschrift** zur Lösung eines Problems oder einer bestimmten Art von Problemen (einer **Problemklasse**) in **endlich vielen Schritten**[cite: 312].
#
# Ein Algorithmus löst also nicht nur die Aufgabe "Sortiere die Zahlen [3, 1, 2]", sondern die Problemklasse "Sortiere eine beliebige Liste von Zahlen". [cite_start]Die konkreten Zahlen sind dabei die **Eingabeparameter**, die sortierte Liste ist die **Ausgabe**[cite: 328, 329].
#
# ---
# > ### 👨‍🏫 **VISUALISIERUNG & DEMO (Live via Teams)**
# >
# > **Skizze 1: Die Herkunft**
# > * Zeichne am Whiteboard eine einfache Zeitleiste.
# > * Markiere einen Punkt bei "ca. 825 n. Chr." und schreibe "al-Chwarizmi".
# > * Zeichne einen großen Pfeil von diesem Punkt zum heutigen Begriff **"Algorithmus"**.
# > * Skizziere daneben eine "Black Box" mit der Beschriftung "Algorithmus". Zeichne einen Pfeil "Eingabe" (z.B. eine unsortierte Liste) hinein und einen Pfeil "Ausgabe" (eine sortierte Liste) heraus.
#
# ---
# > ### 🗣️ **MANUSKRIPT LEHRER (Stichpunkte)**
# >
# > * **Einstieg:** "Bevor wir lernen, komplexe Algorithmen zu *schreiben*, müssen wir verstehen, was ein Algorithmus überhaupt *ist*. Und die Idee dahinter ist fast 1200 Jahre alt."
# > * **Kernbotschaft:** "Ein Algorithmus ist mehr als eine Lösung für ein Einzelproblem. Es ist eine universelle Maschine zur Lösung einer ganzen *Klasse* von Problemen. Unser Sortier-Algorithmus muss mit jeder denkbaren Liste von Zahlen klarkommen."
# > * **Interaktion:** "Was sind andere 'Problemklassen' aus eurem Alltag, für die es Algorithmen gibt?" (z.B. Wäsche waschen, eine Route finden, Kaffee kochen).
#
# ---
# ### **📝 SKRIPT (für Präsentation / Notebook)**
#
# #### **1.2 Die 4 entscheidenden Eigenschaften von Algorithmen**
#
# Nicht jede Anleitung ist ein guter Algorithmus. In der Informatik muss ein Algorithmus vier entscheidende Eigenschaften erfüllen:
#
# 1.  [cite_start]**Endlichkeit (Finiteness):** Die **Beschreibung** des Algorithmus muss eine endliche Länge haben[cite: 336]. Ein Rezept mit unendlich vielen Schritten ist unbrauchbar.
# 2.  [cite_start]**Termination:** Der Algorithmus muss nach endlich vielen Schritten zu einem **Ende** kommen und ein Ergebnis liefern[cite: 337, 338, 421]. Eine Schleife, die unter bestimmten Umständen nie endet, verletzt dieses Prinzip.
# 3.  [cite_start]**Determinismus:** Jeder Schritt im Algorithmus muss **eindeutig beschrieben** sein[cite: 339, 340]. Es darf keinen Raum für Interpretation geben. "Eine Prise Salz" ist eine schlechte Anweisung; "Gib 2g Salz hinzu" ist deterministisch. [cite_start]Zu jedem Zeitpunkt muss der nächste Schritt klar sein[cite: 347].
# 4.  [cite_start]**Determiniertheit:** Für die gleiche Eingabe muss ein Algorithmus auch immer die **gleiche Ausgabe** liefern[cite: 341, 342, 349].
#
# Der feine Unterschied: **Determinismus** beschreibt den **Weg** (der Ablauf ist immer exakt gleich), **Determiniertheit** beschreibt das **Ziel** (das Ergebnis ist immer exakt gleich). [cite_start]Ein deterministischer Algorithmus ist immer auch determiniert[cite: 342].
#
# ---
# > ### 👨‍🏫 **VISUALISIERUNG & DEMO (Live via Teams)**
# >
# > **Skizze 2: Termination**
# > * Zeichne einen Kreis (Start) und einen Pfeil zu einem Kasten ("Schleife").
# > * Zeichne einen Pfeil, der von der Schleife im Kreis wieder auf sich selbst zeigt.
# > * **Fall A (terminiert):** Zeichne einen zweiten Pfeil, der aus der Schleife herausführt, zu einem Kreis (Ende). Beschrifte diesen Pfeil mit einer klaren Abbruchbedingung (z.B. "wenn Zähler = 0").
# > * **Fall B (nicht-terminierend):** Zeichne daneben nur die Endlosschleife ohne Ausweg. Streiche sie rot durch und schreibe "Verletzt Termination!".
# >
# > **Skizze 3: Determinismus**
# > * Zeichne einen Weg, der sich gabelt.
# > * **Fall A (deterministisch):** An der Gabelung steht ein Schild: "Wenn `x > 10`, gehe links, sonst rechts". Der Weg ist klar.
# > * **Fall B (nicht-deterministisch):** An der Gabelung steht ein Schild: "Gehe in eine beliebige Richtung". Der Weg ist unklar.
#
# ---
# > ### 🗣️ **MANUSKRIPT LEHRER (Stichpunkte)**
# >
# > * **Beispiele zu den Eigenschaften:**
# >     * **Termination:** "Ein Navi, das sagt 'Fahren Sie 500m, dann fahren Sie 500m, dann fahren Sie 500m...' ohne jemals anzukommen, verletzt das Terminations-Prinzip."
# >     * **Determinismus:** "Stellt euch vor, in einem Kochrezept stünde nur 'Zutaten vermischen' statt 'Verrühre Mehl und Zucker, gib dann die Eier hinzu'. Der Ablauf wäre nicht eindeutig – das verletzt den Determinismus."
# > * **Interaktion:** "Lasst uns über den Unterschied zwischen Determinismus und Determiniertheit nachdenken. Ein Algorithmus, der den Ausgang aus einem Labyrinth sucht, könnte zufällige Wege ausprobieren (nicht-deterministisch), aber er wird immer dasselbe Ergebnis liefern: den Ausgang (determiniert)."
#
# ---
# ### **📝 SKRIPT (für Präsentation / Notebook)**
#
# #### **1.3 Effizienz: Nicht alle Wege führen gleich schnell nach Rom**
#
# Ein Algorithmus, der korrekt ist und alle Eigenschaften erfüllt, ist nicht automatisch ein *guter* Algorithmus. [cite_start]Eine entscheidende Frage ist die nach der **Effizienz**: Wie viele Ressourcen verbraucht unser Algorithmus? [cite: 431]
#
# Die zwei wichtigsten Ressourcen sind:
# * [cite_start]**Zeit (Laufzeitkomplexität):** Wie viele Rechenschritte benötigt der Algorithmus in Abhängigkeit von der Größe der Eingabedaten? [cite: 433, 434]
# * [cite_start]**Speicher (Speicherplatzkomplexität):** Wie viel Arbeitsspeicher (RAM) benötigt der Algorithmus, um seine Aufgabe zu erfüllen? [cite: 432]
#
# Ein Algorithmus, der für 10 Elemente eine Sekunde braucht, für 100 Elemente aber schon zwei Stunden, ist für die Praxis unbrauchbar. Die Suche nach effizienten Algorithmen ist eine der zentralen Aufgaben der Informatik.
#
# ---
# > ### 👨‍🏫 **VISUALISIERUNG & DEMO (Live via Teams)**
# >
# > **Skizze 4: Effizienz visualisieren**
# > * Zeichne ein einfaches Koordinatensystem. X-Achse: "Größe der Eingabe (z.B. Anzahl Zahlen in einer Liste)". Y-Achse: "Benötigte Zeit".
# > * **Linie 1 (effizient):** Zeichne eine flache, leicht ansteigende Kurve. Beschrifte sie: "Guter, effizienter Algorithmus".
# > * **Linie 2 (ineffizient):** Zeichne eine sehr steil ansteigende, exponentielle Kurve. Beschrifte sie: "Schlechter, ineffizienter Algorithmus".
# > * Zeige, dass bei kleiner Eingabe beide Algorithmen schnell sind, der Unterschied aber bei großer Eingabe dramatisch wird.
#
# ---
# > ### 🗣️ **MANUSKRIPT LEHRER (Stichpunkte)**
# >
# > * **Analogie:** "Stellt euch vor, ihr sollt eine Telefonnummer in einem Telefonbuch finden. Der 'schlechte' Algorithmus wäre, bei 'A' anzufangen und jede einzelne Seite durchzublättern, bis ihr bei 'Zimmermann' ankommt. Der 'gute' Algorithmus wäre, das Buch in der Mitte aufzuschlagen und zu schauen, ob man davor oder danach weitersuchen muss (Binäre Suche)."
# > * **Kernbotschaft:** "Für kleine Datenmengen ist Effizienz oft egal. Aber in der realen Welt, wo wir Millionen von Datensätzen verarbeiten, ist ein effizienter Algorithmus der Unterschied zwischen einem funktionierenden und einem unbrauchbaren Programm."
# > * **Ausblick:** "Den Bubble Sort, den wir uns bald ansehen, ist ein gutes Beispiel für einen Algorithmus, der leicht zu verstehen, aber sehr ineffizient ist."
